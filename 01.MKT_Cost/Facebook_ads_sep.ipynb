# %%
import os, sys, inspect
sys.path.append('/Users/linh.nguyen4')

import pandas as pd
from pathlib import Path
import glob as glob
import os
import numpy as np
from datetime import datetime, timedelta, date
from slack_sdk import WebClient

from avay_bq import AvayBQServiceAcc
from Downloads.da_utils.bigquery_service.BigqueryClient import BigqueryClient
from Downloads.da_utils.bigquery_service.BigqueryService import BigqueryService
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 2000

# %%
adc_path = Path('/Users/linh.nguyen4/.config/gcloud/application_default_credentials.json')
bq_client = BigqueryClient(billing_project_id='prj-ts-p-analytic-8057', adc_file_path=adc_path)
bq_repo = BigqueryService(bq_client)
bq_client_avay = BigqueryClient(billing_project_id='avay-a9925', adc_file_path=adc_path)
bq_repo_avay = BigqueryService(bq_client_avay)

channel_id = 'D04E3QZSD7U'
bot_auth_token = 'xoxb-3458316355-4272711174212-TYd7W16TXdGA0AXYujddJBET'
slack_client = WebClient(token = bot_auth_token)

# %%
mapping = bq_repo_avay.get_data_from_query_into_pandas(
    f"""
    select distinct
        campaign_name as campaign,
        adset_name as adgroup
    from `avay-a9925.dwh.ad_insights`
    where account_id != '809675919382650'
    """)
mapping
# Out:
#                           campaign                              adgroup
# 0                    pros_avay_upl               1308_accepted_1m_intra
# 1           EVO_Conv_TPB DOP_Esign              EVO_Conv_TPB DOP_HighQL
# 2                    pros_avay_upl                otp_verified_1m_intra
# 3            EVO_Conv_TPB DOP_vOTP       EVO_Conv_TPB DOP_ FoodandDrink
# 4           EVO_Conv_TPB DOP_Esign          EVO_Conv_TPB DOP_Investment
# ..                             ...                                  ...
# 126  EVO_Conv_TPB DOP_Contact info   EVO_Conv_TPB DOP_Food_Contact info
# 127                  pros_avay_upl         Conv_LALFE-Accepted10%_20-45
# 128                       EVO_Mess                     EVO_Mess_Banking
# 129                  pros_avay_upl  Conv_LAL2%FE_VerifiedOTP_ExOTP90day
# 130         EVO_Conv_TPB DOP_Esign            EVO_Conv_LAL4%Esign_Esign
#
# [131 rows x 2 columns]

# %%
df = pd.read_csv('/Users/linh.nguyen4/Downloads/02.EVO/raw_data/neo-Ads-21-Sep-202321-Sep-2023.csv')
df
# Out:
#    Reporting starts Reporting ends        Ad name     Ad delivery  \
# 0        2023-09-21     2023-09-21        Video_2        inactive
# 1        2023-09-21     2023-09-21        Video_1        inactive
# 2        2023-09-21     2023-09-21        Video_3        inactive
# 3        2023-09-21     2023-09-21     Image_1001        inactive
# 4        2023-09-21     2023-09-21        Video_3        inactive
# 5        2023-09-21     2023-09-21     Image_1001        inactive
# 6        2023-09-21     2023-09-21  Carousel_1001  not_delivering
# 7        2023-09-21     2023-09-21  Carousel_1001        inactive
# 8        2023-09-21     2023-09-21     Image_1002        inactive
# 9        2023-09-21     2023-09-21     Image_1002        inactive
# 10       2023-09-21     2023-09-21     Video_1201        inactive
# 11       2023-09-21     2023-09-21     Image_1102        inactive
# 12       2023-09-21     2023-09-21     Image_0103  not_delivering
# ...

# %%
df.rename(columns = {
    'Reporting starts':'date',
    'Ad set name':'adgroup',
    'Ad name': 'criteria',
    'Clicks (all)': 'clicks',
    'Impressions': 'impressions',
    'Amount spent (VND)': 'cost',
    'Campaign name': 'campaign'
}, inplace = True)
df = df[['date', 'adgroup', 'criteria', 'clicks', 'impressions', 'cost',
       'campaign']]
df.to_csv('/Users/linh.nguyen4/Downloads/02.EVO/raw_data/facebook_ad_sep_21.csv', index = False)
